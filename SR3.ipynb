# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv( "C:/Users/CC/settlement.csv")

# %%
 print(dataframe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434 entries, 0 to 433
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   is_cluster               434 non-null    object
#  1   pocket_name              434 non-null    object
#  2   pocket_alias             192 non-null    object
#  3   ward_id                  434 non-null    int64
#  4   ward_councillor          434 non-null    object
#  5   avg_hhsize               434 non-null    float64
#  6   area_ha                  434 non-null    float64
#  7   density_dwellings        434 non-null    float64
#  8   structure_count          434 non-null    int64
#  9   age_of_is                434 non-null    object
#  10  upgrade_category         434 non-null    object
#  11  temp_sanitation          434 non-null    float64
#  12  toilets_full_flush       434 non-null    float64
#  13  toilets_chemical         434 non-null    float64
# ...

# %%
summary_stats = dataframe.describe()
print(summary_stats)
# Out:
#             ward_id  avg_hhsize     area_ha  density_dwellings  \
# count  4.340000e+02  434.000000  434.000000         434.000000
# mean   1.910006e+07    3.337143    4.462938         183.057795
# std    3.102414e+01    0.535691   32.968974         182.105873
# min    1.910000e+07    2.190000    0.010000           0.000000
# 25%    1.910004e+07    2.892500    0.140000          90.022903
# 50%    1.910007e+07    3.230000    0.389000         174.685262
# 75%    1.910009e+07    3.710000    1.904000         254.274750
# max    1.910011e+07    5.110000  669.406000        3007.299270
#
#        structure_count  temp_sanitation  toilets_full_flush  toilets_chemical  \
# count       434.000000       434.000000          434.000000        434.000000
# mean        337.744240        31.369426           31.283410         11.582949
# std         859.580015        43.844564           87.902084         48.968423
# min           0.000000         0.000000            0.000000          0.000000
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='pocket_name', y='density_dwellings', data=df, order=df.sort_values('density_dwellings', ascending=False)['pocket_name'])
plt.title('Population Density in Informal Settlements')
plt.xlabel('Pocket Name')
plt.ylabel('Density of Dwellings')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['avg_hhsize'], bins=20, kde=True)
plt.title('Distribution of Average Household Size')
plt.xlabel('Average Household Size')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\CC\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sanitation_counts = df[['toilets_full_flush', 'toilets_chemical', 'toilets_portable', 'toilets_container', 'toilets_other']].sum()
plt.figure(figsize=(8, 8))
plt.pie(sanitation_counts, labels=sanitation_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Access to Sanitation Facilities')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='density_dwellings', y='avg_hhsize', data=df)
plt.title('Correlation between Density of Dwellings and Average Household Size')
plt.xlabel('Density of Dwellings')
plt.ylabel('Average Household Size')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['structure_count'])
plt.title('Distribution of Structure Count')
plt.xlabel('Structure Count')
plt.show()
